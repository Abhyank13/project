# %% [markdown]
# # Theatre System

# %%
#Create Theatre ticket booking system


# number of seats limited
# normal / recliner
# set prices accordingly
# add combos 
# display bill
# go to next person


print("-------------------------------------welcome to inox---------------------------------")


normal=200
nprice=250

recliner=25
rprice=350


def combos():
    
    cprice=0
   
    if a==1:
        cprice=400+amount
        
    elif a==2:
        cprice=500+amount
    elif a==3:
        cprice=450+amount
    elif a==4:
        cprice=350+amount
    return(cprice)   


amount=0

while True:
    name=input("Enter your Name: ")
    seats=input("which seat you want to book normal (₹250) or recliner(₹350): ")
    
    
    if seats=="normal":
        
        if normal > 0:
            count=int(input("how many seats you want to book: "))
            amount+=nprice*count
            normal-=count
            
            print("----------------------------------------------------------")
            print(name,"Your bill is ",amount)
            print("----------------------------------------------------------")

            
            combo=input("Do You Want Any Combos: ")
            if combo=="yes":
                print("""press 1 to add: Cheese Popcorn and 1 pepsi (₹400)
                         press 2 to add: Cheese Popcorn and 2 pepsi (₹500)
                         press 3 to add: salted Popcorn and 1 pepsi (₹450)
                         press 4 to add: salted Popcorn and 2 pepsi (₹350)""")
                a=int(input("Select Your Combo: "))
                
                print("----------------------------------------------------------")
                print(name,"Your Total Bill is: ",combos())
                print("----------------------------------------------------------")
                print("Total seats left",normal)
                print("----------------------------------------------------------")
                
                
                
                
                
            else:
                print("----------------------------------------------------------")
                print(name,"Your Total Bill is:",amount)
                print("----------------------------------------------------------")
                print("Total seats left",normal)
                print("----------------------------------------------------------")
                
                
            j=input("Do you want to book more tickets: ")
            
            if j=="yes":
                continue
            else:
                break
            
            
            
        else:
            print("There is no normal seats avialable try recliner seats")
            
    elif seats=="recliner":
        if recliner > 0:
            count=int(input("how many seats you want to book: "))
            amount+=rprice*count
            recliner-=count
            print("----------------------------------------------------------")
            print(name,"YOUR BILL IS: ",amount)
            print("----------------------------------------------------------")
    
            
            combo=input("Do You Want Any Combos: ")
            if combo=="yes":
                print("""press 1 to add: Cheese Popcorn and 1 pepsi (₹400)
                         press 2 to add: Cheese Popcorn and 2 pepsi (₹500)
                         press 3 to add: salted Popcorn and 1 pepsi (₹450)
                         press 4 to add: salted Popcorn and 2 pepsi (₹350)
                         """)
                a=int(input("Select Your Combo: "))
                print("----------------------------------------------------------")
                print(name,"Your Total Bill is: ",combos())
                print("----------------------------------------------------------")
                print("Total seats left",recliner) 
                print("----------------------------------------------------------")
                
                
                
                
            else:
                print("----------------------------------------------------------")
                print(name,"Your Total Bill is:",amount)
                print("----------------------------------------------------------")
                print("Total seats left",recliner)
                print("----------------------------------------------------------")
                
            j=input("Do you want to book more tickets: ")
            
            if j=="yes":
                continue
            else:
                break    
                
                
        else:
            print("----------------------------------------------------------")
            print("There is no recliner seats avialable try normal seats")
            print("----------------------------------------------------------")
            print("Total seats left",recliner)
            print("----------------------------------------------------------")
            
    else:
        print("HouseFull ")
# Out:
# -------------------------------------welcome to inox---------------------------------
# Enter your Name: abhi
# which seat you want to book normal (₹250) or recliner(₹350): recliner
# how many seats you want to book: 8
# ----------------------------------------------------------
# abhi YOUR BILL IS:  2800
# ----------------------------------------------------------
# Do You Want Any Combos: yes
# press 1 to add: Cheese Popcorn and 1 pepsi (₹400)
#                          press 2 to add: Cheese Popcorn and 2 pepsi (₹500)
#                          press 3 to add: salted Popcorn and 1 pepsi (₹450)
#                          press 4 to add: salted Popcorn and 2 pepsi (₹350)
#
# Select Your Combo: 3
# ----------------------------------------------------------
# abhi Your Total Bill is:  3250
# ----------------------------------------------------------
# Total seats left 17
# ----------------------------------------------------------
# Do you want to book more tickets: no
